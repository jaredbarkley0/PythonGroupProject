# %% [markdown]
# # BAIS 6040 Programming in Python
#
# ## Spring 2021
#
# ## Group 3 Homework 6

# %%
# Import libraries

import pandas as pd

# %%
# Loading in project data for use in Homework 6

compiledcountydata_dir = "https://raw.githubusercontent.com/jaredbarkley0/PythonGroupProject/master/MN%20County%20Data_032021.csv"
compiledcountydata = pd.read_csv(compiledcountydata_dir)
compiledcountydata
# Out:
#     Unnamed: 0           County  Total Positive Cases  Total Deaths  \
# 0            0           Aitkin                  1191            33
# 1            1            Anoka                 33391           390
# 2            2           Becker                  3131            42
# 3            3         Beltrami                  3386            51
# 4            4           Benton                  4482            90
# ..         ...              ...                   ...           ...
# 83          83           Wilkin                   677            11
# 84          84           Winona                  4193            49
# 85          85           Wright                 12554           116
# 86          86  Yellow Medicine                   977            17
# 87          87  Unknown/Missing                   444             0
#
#     Total No Longer Needing Isolation  Pop Density  Density Factor  \
# 0                                1147          8.0      148.875000
# 1                               32583        753.9       44.291020
# 2                                3032         22.8      137.324561
# 3                                3293         14.8      228.783784
# 4                                4348         94.4       47.478814
# ..                                ...          ...             ...
# 83                                654          8.7       77.816092
# 84                               4087         79.9       52.478098
# 85                              12290        178.3       70.409422
# 86                                957         13.4       72.910448
# 87                                437          NaN             NaN
#
#     Casesinfacility  FacilitiesinCounty
# 0             118.0                 4.0
# 1            1675.0                35.0
# 2             294.0                 8.0
# 3             264.0                11.0
# 4             557.0                11.0
# ..              ...                 ...
# 83             36.0                 2.0
# 84            277.0                 9.0
# 85            687.0                20.0
# 86             79.0                 3.0
# 87              NaN                 NaN
#
# [88 rows x 9 columns]

# %%
# Removing unnecessary columns

compiledcountydata[["County","Total Positive Cases", "Total Deaths", "Pop Density", "Density Factor", "Casesinfacility","FacilitiesinCounty"]]
# Out:
#              County  Total Positive Cases  Total Deaths  Pop Density  \
# 0            Aitkin                  1191            33          8.0
# 1             Anoka                 33391           390        753.9
# 2            Becker                  3131            42         22.8
# 3          Beltrami                  3386            51         14.8
# 4            Benton                  4482            90         94.4
# ..              ...                   ...           ...          ...
# 83           Wilkin                   677            11          8.7
# 84           Winona                  4193            49         79.9
# 85           Wright                 12554           116        178.3
# 86  Yellow Medicine                   977            17         13.4
# 87  Unknown/Missing                   444             0          NaN
#
#     Density Factor  Casesinfacility  FacilitiesinCounty
# 0       148.875000            118.0                 4.0
# 1        44.291020           1675.0                35.0
# 2       137.324561            294.0                 8.0
# 3       228.783784            264.0                11.0
# 4        47.478814            557.0                11.0
# ..             ...              ...                 ...
# 83       77.816092             36.0                 2.0
# 84       52.478098            277.0                 9.0
# 85       70.409422            687.0                20.0
# 86       72.910448             79.0                 3.0
# 87             NaN              NaN                 NaN
#
# [88 rows x 7 columns]

# %% [markdown]
# # Matplotlib

# %% [markdown]
# # Seaborn

# %% [markdown]
# # Plotly
